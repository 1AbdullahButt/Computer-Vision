# %%
# !pip install ultralytics

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.3.0+cu121'

# %%
# !yolo task = detect mode = predict model = yolov8n.pt source = '/content/Image.jpg'
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Image.jpg: 448x640 10 persons, 1 bus, 3 traffic lights, 2 backpacks, 2 handbags, 124.6ms
# Speed: 3.8ms preprocess, 124.6ms inference, 1956.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

model.predict(source = '/content/Image.jpg', save = True)
# Out:
# image 1/1 /content/Image.jpg: 448x640 10 persons, 1 bus, 3 traffic lights, 2 backpacks, 2 handbags, 103.6ms
# Speed: 3.8ms preprocess, 103.6ms inference, 1353.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# !yolo task = detect mode = predict model = yolov8n.pt source = '/content/Image.jpg' conf = 0.5 # thershold or probability
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Image.jpg: 448x640 8 persons, 1 bus, 1 traffic light, 1 backpack, 102.1ms
# Speed: 3.7ms preprocess, 102.1ms inference, 1324.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = yolov8n.pt source = '/content/Image.jpg' conf = 0.7 save_txt = True
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Image.jpg: 448x640 5 persons, 1 bus, 102.1ms
# Speed: 3.7ms preprocess, 102.1ms inference, 1449.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4
# 1 label saved to runs/detect/predict4/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = yolov8n.pt source = '/content/Image.jpg' conf = 0.7 save_txt = True save_crop = True
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Image.jpg: 448x640 5 persons, 1 bus, 103.3ms
# Speed: 3.9ms preprocess, 103.3ms inference, 1338.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict5
# 1 label saved to runs/detect/predict5/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = yolov8n.pt source = '/content/Image.jpg' conf = 0.7 show_labels = False
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Image.jpg: 448x640 5 persons, 1 bus, 100.3ms
# Speed: 3.8ms preprocess, 100.3ms inference, 1430.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = yolov8n.pt source = '/content/Video.mp4'
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/1314) /content/Video.mp4: 384x640 1 car, 117.8ms
# video 1/1 (frame 2/1314) /content/Video.mp4: 384x640 1 car, 7.6ms
# video 1/1 (frame 3/1314) /content/Video.mp4: 384x640 1 car, 7.0ms
# video 1/1 (frame 4/1314) /content/Video.mp4: 384x640 1 car, 6.8ms
# video 1/1 (frame 5/1314) /content/Video.mp4: 384x640 2 cars, 6.9ms
# video 1/1 (frame 6/1314) /content/Video.mp4: 384x640 2 cars, 6.9ms
# video 1/1 (frame 7/1314) /content/Video.mp4: 384x640 2 cars, 6.5ms
# video 1/1 (frame 8/1314) /content/Video.mp4: 384x640 2 cars, 6.7ms
# video 1/1 (frame 9/1314) /content/Video.mp4: 384x640 2 cars, 7.4ms
# video 1/1 (frame 10/1314) /content/Video.mp4: 384x640 2 cars, 6.6ms
# video 1/1 (frame 11/1314) /content/Video.mp4: 384x640 2 cars, 7.3ms
# ...

# %% [markdown]
# # Semantic Segmentation

# %%
# !yolo task = segment mode = predict model = yolov8s-seg.pt source = '/content/Image.jpg'
# Out:
# Ultralytics YOLOv8.2.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
#
# image 1/1 /content/Image.jpg: 448x640 12 persons, 1 bus, 2 traffic lights, 4 backpacks, 5 handbags, 119.6ms
# Speed: 3.8ms preprocess, 119.6ms inference, 1874.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

model.predict(source ='/content/Image.jpg', save = True, show_labels = True)
# Out:
# image 1/1 /content/Image.jpg: 448x640 10 persons, 1 bus, 3 traffic lights, 2 backpacks, 2 handbags, 10.9ms
# Speed: 10.6ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
